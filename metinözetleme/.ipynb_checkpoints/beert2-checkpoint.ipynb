# %%
# !pip install transformers==2.2.0
# !pip install bert-extractive-summarizer
# !pip install spacy==2.0.12
# Out:
# Collecting transformers==2.2.0
#   Using cached transformers-2.2.0-py3-none-any.whl (360 kB)
# Requirement already satisfied: numpy in c:\users\erdin\anaconda3\lib\site-packages (from transformers==2.2.0) (1.19.2)
# Requirement already satisfied: boto3 in c:\users\erdin\anaconda3\lib\site-packages (from transformers==2.2.0) (1.20.37)
# Requirement already satisfied: sacremoses in c:\users\erdin\anaconda3\lib\site-packages (from transformers==2.2.0) (0.0.46)
# Requirement already satisfied: sentencepiece in c:\users\erdin\anaconda3\lib\site-packages (from transformers==2.2.0) (0.1.96)
# Requirement already satisfied: requests in c:\users\erdin\anaconda3\lib\site-packages (from transformers==2.2.0) (2.27.1)
# Requirement already satisfied: regex in c:\users\erdin\anaconda3\lib\site-packages (from transformers==2.2.0) (2021.11.10)
# Requirement already satisfied: tqdm in c:\users\erdin\anaconda3\lib\site-packages (from transformers==2.2.0) (4.50.2)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in c:\users\erdin\anaconda3\lib\site-packages (from boto3->transformers==2.2.0) (0.5.0)
# Requirement already satisfied: botocore<1.24.0,>=1.23.37 in c:\users\erdin\anaconda3\lib\site-packages (from boto3->transformers==2.2.0) (1.23.37)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in c:\users\erdin\anaconda3\lib\site-packages (from boto3->transformers==2.2.0) (0.10.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\erdin\anaconda3\lib\site-packages (from requests->transformers==2.2.0) (2020.6.20)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\erdin\anaconda3\lib\site-packages (from requests->transformers==2.2.0) (2.10)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\erdin\anaconda3\lib\site-packages (from requests->transformers==2.2.0) (2.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\erdin\anaconda3\lib\site-packages (from requests->transformers==2.2.0) (1.26.8)
# Requirement already satisfied: click in c:\users\erdin\anaconda3\lib\site-packages (from sacremoses->transformers==2.2.0) (7.1.2)
# Requirement already satisfied: six in c:\users\erdin\anaconda3\lib\site-packages (from sacremoses->transformers==2.2.0) (1.15.0)
# Requirement already satisfied: joblib in c:\users\erdin\anaconda3\lib\site-packages (from sacremoses->transformers==2.2.0) (0.17.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\erdin\anaconda3\lib\site-packages (from botocore<1.24.0,>=1.23.37->boto3->transformers==2.2.0) (2.8.1)
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.15.0
#     Uninstalling transformers-4.15.0:
#       Successfully uninstalled transformers-4.15.0
# Successfully installed transformers-2.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# simpletransformers 0.63.3 requires transformers>=4.6.0, but you have transformers 2.2.0 which is incompatible.
# sentence-transformers 2.1.0 requires transformers<5.0.0,>=4.6.0, but you have transformers 2.2.0 which is incompatible.
# Requirement already satisfied: bert-extractive-summarizer in c:\users\erdin\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: transformers in c:\users\erdin\anaconda3\lib\site-packages (from bert-extractive-summarizer) (2.2.0)
# Requirement already satisfied: spacy in c:\users\erdin\anaconda3\lib\site-packages (from bert-extractive-summarizer) (3.2.1)
# Requirement already satisfied: scikit-learn in c:\users\erdin\anaconda3\lib\site-packages (from bert-extractive-summarizer) (0.23.2)
# Requirement already satisfied: joblib>=0.11 in c:\users\erdin\anaconda3\lib\site-packages (from scikit-learn->bert-extractive-summarizer) (0.17.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\erdin\anaconda3\lib\site-packages (from scikit-learn->bert-extractive-summarizer) (2.1.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\erdin\anaconda3\lib\site-packages (from scikit-learn->bert-extractive-summarizer) (1.19.2)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\erdin\anaconda3\lib\site-packages (from scikit-learn->bert-extractive-summarizer) (1.5.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\erdin\anaconda3\lib\site-packages (from spacy->bert-extractive-summarizer) (1.0.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\erdin\anaconda3\lib\site-packages (from spacy->bert-extractive-summarizer) (3.3.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\erdin\anaconda3\lib\site-packages (from spacy->bert-extractive-summarizer) (3.0.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\erdin\anaconda3\lib\site-packages (from spacy->bert-extractive-summarizer) (21.3)
# Requirement already satisfied: jinja2 in c:\users\erdin\anaconda3\lib\site-packages (from spacy->bert-extractive-summarizer) (2.11.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\erdin\anaconda3\lib\site-packages (from spacy->bert-extractive-summarizer) (2.0.6)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\erdin\anaconda3\lib\site-packages (from spacy->bert-extractive-summarizer) (0.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\erdin\anaconda3\lib\site-packages (from spacy->bert-extractive-summarizer) (2.27.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\erdin\anaconda3\lib\site-packages (from spacy->bert-extractive-summarizer) (1.0.6)
# Requirement already satisfied: setuptools in c:\users\erdin\anaconda3\lib\site-packages (from spacy->bert-extractive-summarizer) (50.3.1.post20201107)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in c:\users\erdin\anaconda3\lib\site-packages (from spacy->bert-extractive-summarizer) (8.0.13)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in c:\users\erdin\anaconda3\lib\site-packages (from spacy->bert-extractive-summarizer) (3.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\users\erdin\anaconda3\lib\site-packages (from spacy->bert-extractive-summarizer) (2.4.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\erdin\anaconda3\lib\site-packages (from spacy->bert-extractive-summarizer) (0.7.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\erdin\anaconda3\lib\site-packages (from spacy->bert-extractive-summarizer) (0.9.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\erdin\anaconda3\lib\site-packages (from spacy->bert-extractive-summarizer) (1.8.2)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\erdin\anaconda3\lib\site-packages (from spacy->bert-extractive-summarizer) (0.6.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\erdin\anaconda3\lib\site-packages (from spacy->bert-extractive-summarizer) (4.50.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\erdin\anaconda3\lib\site-packages (from spacy->bert-extractive-summarizer) (2.0.6)
# Requirement already satisfied: boto3 in c:\users\erdin\anaconda3\lib\site-packages (from transformers->bert-extractive-summarizer) (1.20.37)
# Requirement already satisfied: sacremoses in c:\users\erdin\anaconda3\lib\site-packages (from transformers->bert-extractive-summarizer) (0.0.46)
# Requirement already satisfied: regex in c:\users\erdin\anaconda3\lib\site-packages (from transformers->bert-extractive-summarizer) (2021.11.10)
# Requirement already satisfied: sentencepiece in c:\users\erdin\anaconda3\lib\site-packages (from transformers->bert-extractive-summarizer) (0.1.96)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\erdin\anaconda3\lib\site-packages (from packaging>=20.0->spacy->bert-extractive-summarizer) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\erdin\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy->bert-extractive-summarizer) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\erdin\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy->bert-extractive-summarizer) (3.7.4.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\erdin\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy->bert-extractive-summarizer) (2.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\erdin\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy->bert-extractive-summarizer) (2020.6.20)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\erdin\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy->bert-extractive-summarizer) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\erdin\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy->bert-extractive-summarizer) (2.10)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\erdin\anaconda3\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy->bert-extractive-summarizer) (7.1.2)
# Requirement already satisfied: botocore<1.24.0,>=1.23.37 in c:\users\erdin\anaconda3\lib\site-packages (from boto3->transformers->bert-extractive-summarizer) (1.23.37)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in c:\users\erdin\anaconda3\lib\site-packages (from boto3->transformers->bert-extractive-summarizer) (0.10.0)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in c:\users\erdin\anaconda3\lib\site-packages (from boto3->transformers->bert-extractive-summarizer) (0.5.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\erdin\anaconda3\lib\site-packages (from jinja2->spacy->bert-extractive-summarizer) (1.1.1)
# Requirement already satisfied: six in c:\users\erdin\anaconda3\lib\site-packages (from sacremoses->transformers->bert-extractive-summarizer) (1.15.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\erdin\anaconda3\lib\site-packages (from botocore<1.24.0,>=1.23.37->boto3->transformers->bert-extractive-summarizer) (2.8.1)
# Collecting spacy==2.0.12
#   Using cached spacy-2.0.12.tar.gz (22.0 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy>=1.7 in c:\users\erdin\anaconda3\lib\site-packages (from spacy==2.0.12) (1.19.2)
# Collecting murmurhash<0.29,>=0.28
#   Using cached murmurhash-0.28.0.tar.gz (23 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting cymem<1.32,>=1.30
#   Using cached cymem-1.31.2.tar.gz (33 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting preshed<2.0.0,>=1.0.0
#   Using cached preshed-1.0.1.tar.gz (112 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting thinc<6.11.0,>=6.10.3
#   Using cached thinc-6.10.3.tar.gz (1.2 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting plac<1.0.0,>=0.9.6
#   Using cached plac-0.9.6-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: ujson>=1.35 in c:\users\erdin\anaconda3\lib\site-packages (from spacy==2.0.12) (4.0.1)
# Collecting dill<0.3,>=0.2
#   Using cached dill-0.2.9-py3-none-any.whl
# Collecting regex==2017.4.5
#   Using cached regex-2017.04.05.tar.gz (601 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\erdin\anaconda3\lib\site-packages (from spacy==2.0.12) (2.27.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\erdin\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==2.0.12) (2.10)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\erdin\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==2.0.12) (2.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\erdin\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==2.0.12) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\erdin\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==2.0.12) (2020.6.20)
# Requirement already satisfied: msgpack<1.0.0,>=0.5.6 in c:\users\erdin\anaconda3\lib\site-packages (from thinc<6.11.0,>=6.10.3->spacy==2.0.12) (0.6.2)
# Collecting msgpack-numpy<1.0.0,>=0.4.1
#   Using cached msgpack_numpy-0.4.7.1-py2.py3-none-any.whl (6.7 kB)
# Collecting cytoolz<0.10,>=0.9.0
#   Using cached cytoolz-0.9.0.1.tar.gz (443 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting wrapt<1.11.0,>=1.10.0
#   Using cached wrapt-1.10.11-py3-none-any.whl
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in c:\users\erdin\anaconda3\lib\site-packages (from thinc<6.11.0,>=6.10.3->spacy==2.0.12) (4.50.2)
# Requirement already satisfied: six<2.0.0,>=1.10.0 in c:\users\erdin\anaconda3\lib\site-packages (from thinc<6.11.0,>=6.10.3->spacy==2.0.12) (1.15.0)
# Requirement already satisfied: toolz>=0.8.0 in c:\users\erdin\anaconda3\lib\site-packages (from cytoolz<0.10,>=0.9.0->thinc<6.11.0,>=6.10.3->spacy==2.0.12) (0.11.1)
# Building wheels for collected packages: spacy, regex, cymem, murmurhash, preshed, thinc, cytoolz
#   Building wheel for spacy (setup.py): started
#   Building wheel for spacy (setup.py): finished with status 'error'
#   Running setup.py clean for spacy
#   ERROR: Command errored out with exit status 1:
#    command: 'c:\users\erdin\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\erdin\\AppData\\Local\\Temp\\pip-install-5_87qyxw\\spacy_706dd715b6d94b62aa3d506beef5f1ea\\setup.py'"'"'; __file__='"'"'C:\\Users\\erdin\\AppData\\Local\\Temp\\pip-install-5_87qyxw\\spacy_706dd715b6d94b62aa3d506beef5f1ea\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\erdin\AppData\Local\Temp\pip-wheel-vlj1yc0l'
#        cwd: C:\Users\erdin\AppData\Local\Temp\pip-install-5_87qyxw\spacy_706dd715b6d94b62aa3d506beef5f1ea\
#   Complete output (638 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.8
#   creating build\lib.win-amd64-3.8\spacy
#   copying spacy\about.py -> build\lib.win-amd64-3.8\spacy
#   copying spacy\compat.py -> build\lib.win-amd64-3.8\spacy
#   copying spacy\errors.py -> build\lib.win-amd64-3.8\spacy
#   copying spacy\glossary.py -> build\lib.win-amd64-3.8\spacy
#   copying spacy\language.py -> build\lib.win-amd64-3.8\spacy
#   copying spacy\lemmatizer.py -> build\lib.win-amd64-3.8\spacy
#   copying spacy\scorer.py -> build\lib.win-amd64-3.8\spacy
#   copying spacy\util.py -> build\lib.win-amd64-3.8\spacy
#   copying spacy\_ml.py -> build\lib.win-amd64-3.8\spacy
#   copying spacy\__init__.py -> build\lib.win-amd64-3.8\spacy
#   copying spacy\__main__.py -> build\lib.win-amd64-3.8\spacy
#   creating build\lib.win-amd64-3.8\spacy\cli
#   copying spacy\cli\convert.py -> build\lib.win-amd64-3.8\spacy\cli
#   copying spacy\cli\download.py -> build\lib.win-amd64-3.8\spacy\cli
#   copying spacy\cli\evaluate.py -> build\lib.win-amd64-3.8\spacy\cli
#   copying spacy\cli\info.py -> build\lib.win-amd64-3.8\spacy\cli
#   copying spacy\cli\init_model.py -> build\lib.win-amd64-3.8\spacy\cli
#   copying spacy\cli\link.py -> build\lib.win-amd64-3.8\spacy\cli
#   copying spacy\cli\package.py -> build\lib.win-amd64-3.8\spacy\cli
#   copying spacy\cli\profile.py -> build\lib.win-amd64-3.8\spacy\cli
#   copying spacy\cli\train.py -> build\lib.win-amd64-3.8\spacy\cli
#   copying spacy\cli\validate.py -> build\lib.win-amd64-3.8\spacy\cli
#   copying spacy\cli\vocab.py -> build\lib.win-amd64-3.8\spacy\cli
#   copying spacy\cli\_messages.py -> build\lib.win-amd64-3.8\spacy\cli
#   copying spacy\cli\__init__.py -> build\lib.win-amd64-3.8\spacy\cli
#   creating build\lib.win-amd64-3.8\spacy\data
#   copying spacy\data\__init__.py -> build\lib.win-amd64-3.8\spacy\data
#   creating build\lib.win-amd64-3.8\spacy\displacy
#   copying spacy\displacy\render.py -> build\lib.win-amd64-3.8\spacy\displacy
#   copying spacy\displacy\templates.py -> build\lib.win-amd64-3.8\spacy\displacy
#   copying spacy\displacy\__init__.py -> build\lib.win-amd64-3.8\spacy\displacy
#   creating build\lib.win-amd64-3.8\spacy\lang
#   copying spacy\lang\char_classes.py -> build\lib.win-amd64-3.8\spacy\lang
#   copying spacy\lang\entity_rules.py -> build\lib.win-amd64-3.8\spacy\lang
#   copying spacy\lang\lex_attrs.py -> build\lib.win-amd64-3.8\spacy\lang
#   copying spacy\lang\norm_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang
#   copying spacy\lang\punctuation.py -> build\lib.win-amd64-3.8\spacy\lang
#   copying spacy\lang\tag_map.py -> build\lib.win-amd64-3.8\spacy\lang
#   copying spacy\lang\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang
#   copying spacy\lang\__init__.py -> build\lib.win-amd64-3.8\spacy\lang
#   creating build\lib.win-amd64-3.8\spacy\syntax
#   copying spacy\syntax\__init__.py -> build\lib.win-amd64-3.8\spacy\syntax
#   creating build\lib.win-amd64-3.8\spacy\tests
#   copying spacy\tests\conftest.py -> build\lib.win-amd64-3.8\spacy\tests
#   copying spacy\tests\test_matcher.py -> build\lib.win-amd64-3.8\spacy\tests
#   copying spacy\tests\test_misc.py -> build\lib.win-amd64-3.8\spacy\tests
#   copying spacy\tests\test_pickles.py -> build\lib.win-amd64-3.8\spacy\tests
#   copying spacy\tests\test_underscore.py -> build\lib.win-amd64-3.8\spacy\tests
#   copying spacy\tests\util.py -> build\lib.win-amd64-3.8\spacy\tests
#   copying spacy\tests\__init__.py -> build\lib.win-amd64-3.8\spacy\tests
#   creating build\lib.win-amd64-3.8\spacy\tokens
#   copying spacy\tokens\printers.py -> build\lib.win-amd64-3.8\spacy\tokens
#   copying spacy\tokens\underscore.py -> build\lib.win-amd64-3.8\spacy\tokens
#   copying spacy\tokens\__init__.py -> build\lib.win-amd64-3.8\spacy\tokens
#   creating build\lib.win-amd64-3.8\spacy\cli\converters
#   copying spacy\cli\converters\conllu2json.py -> build\lib.win-amd64-3.8\spacy\cli\converters
#   copying spacy\cli\converters\conllubio2json.py -> build\lib.win-amd64-3.8\spacy\cli\converters
#   copying spacy\cli\converters\conll_ner2json.py -> build\lib.win-amd64-3.8\spacy\cli\converters
#   copying spacy\cli\converters\iob2json.py -> build\lib.win-amd64-3.8\spacy\cli\converters
#   copying spacy\cli\converters\__init__.py -> build\lib.win-amd64-3.8\spacy\cli\converters
#   creating build\lib.win-amd64-3.8\spacy\lang\ar
#   copying spacy\lang\ar\examples.py -> build\lib.win-amd64-3.8\spacy\lang\ar
#   copying spacy\lang\ar\lex_attrs.py -> build\lib.win-amd64-3.8\spacy\lang\ar
#   copying spacy\lang\ar\punctuation.py -> build\lib.win-amd64-3.8\spacy\lang\ar
#   copying spacy\lang\ar\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\ar
#   copying spacy\lang\ar\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\ar
#   copying spacy\lang\ar\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\ar
#   creating build\lib.win-amd64-3.8\spacy\lang\bn
#   copying spacy\lang\bn\lemmatizer.py -> build\lib.win-amd64-3.8\spacy\lang\bn
#   copying spacy\lang\bn\morph_rules.py -> build\lib.win-amd64-3.8\spacy\lang\bn
#   copying spacy\lang\bn\punctuation.py -> build\lib.win-amd64-3.8\spacy\lang\bn
#   copying spacy\lang\bn\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\bn
#   copying spacy\lang\bn\tag_map.py -> build\lib.win-amd64-3.8\spacy\lang\bn
#   copying spacy\lang\bn\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\bn
#   copying spacy\lang\bn\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\bn
#   creating build\lib.win-amd64-3.8\spacy\lang\da
#   Building wheel for regex (setup.py): started
#   Building wheel for regex (setup.py): finished with status 'error'
#   Running setup.py clean for regex
#   Building wheel for cymem (setup.py): started
#   Building wheel for cymem (setup.py): finished with status 'error'
#   Running setup.py clean for cymem
#   Building wheel for murmurhash (setup.py): started
#   Building wheel for murmurhash (setup.py): finished with status 'error'
#   Running setup.py clean for murmurhash
#   Building wheel for preshed (setup.py): started
#   Building wheel for preshed (setup.py): finished with status 'error'
#   Running setup.py clean for preshed
#   Building wheel for thinc (setup.py): started
#   Building wheel for thinc (setup.py): finished with status 'error'
#   Running setup.py clean for thinc
#   Building wheel for cytoolz (setup.py): started
#   Building wheel for cytoolz (setup.py): finished with status 'error'
#   Running setup.py clean for cytoolz
# Failed to build spacy regex cymem murmurhash preshed thinc cytoolz
# Installing collected packages: cymem, wrapt, preshed, plac, murmurhash, msgpack-numpy, dill, cytoolz, thinc, regex, spacy
#   Attempting uninstall: cymem
#     Found existing installation: cymem 2.0.6
#     Uninstalling cymem-2.0.6:
#       Successfully uninstalled cymem-2.0.6
#     Running setup.py install for cymem: started
#     Running setup.py install for cymem: finished with status 'error'
#   Rolling back uninstall of cymem
#   Moving to c:\users\erdin\anaconda3\lib\site-packages\cymem-2.0.6.dist-info\
#    from C:\Users\erdin\anaconda3\Lib\site-packages\~ymem-2.0.6.dist-info
#   Moving to c:\users\erdin\anaconda3\lib\site-packages\cymem\
#    from C:\Users\erdin\anaconda3\Lib\site-packages\~ymem
#   copying spacy\lang\da\examples.py -> build\lib.win-amd64-3.8\spacy\lang\da
#   copying spacy\lang\da\lemmatizer.py -> build\lib.win-amd64-3.8\spacy\lang\da
#   copying spacy\lang\da\lex_attrs.py -> build\lib.win-amd64-3.8\spacy\lang\da
#   copying spacy\lang\da\morph_rules.py -> build\lib.win-amd64-3.8\spacy\lang\da
#   copying spacy\lang\da\norm_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\da
#   copying spacy\lang\da\punctuation.py -> build\lib.win-amd64-3.8\spacy\lang\da
#   copying spacy\lang\da\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\da
#   copying spacy\lang\da\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\da
#   copying spacy\lang\da\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\da
#   creating build\lib.win-amd64-3.8\spacy\lang\de
#   copying spacy\lang\de\examples.py -> build\lib.win-amd64-3.8\spacy\lang\de
#   copying spacy\lang\de\lemmatizer.py -> build\lib.win-amd64-3.8\spacy\lang\de
#   copying spacy\lang\de\norm_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\de
#   copying spacy\lang\de\punctuation.py -> build\lib.win-amd64-3.8\spacy\lang\de
#   copying spacy\lang\de\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\de
#   copying spacy\lang\de\syntax_iterators.py -> build\lib.win-amd64-3.8\spacy\lang\de
#   copying spacy\lang\de\tag_map.py -> build\lib.win-amd64-3.8\spacy\lang\de
#   copying spacy\lang\de\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\de
#   copying spacy\lang\de\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\de
#   creating build\lib.win-amd64-3.8\spacy\lang\el
#   copying spacy\lang\el\examples.py -> build\lib.win-amd64-3.8\spacy\lang\el
#   copying spacy\lang\el\lex_attrs.py -> build\lib.win-amd64-3.8\spacy\lang\el
#   copying spacy\lang\el\norm_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\el
#   copying spacy\lang\el\punctuation.py -> build\lib.win-amd64-3.8\spacy\lang\el
#   copying spacy\lang\el\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\el
#   copying spacy\lang\el\tag_map.py -> build\lib.win-amd64-3.8\spacy\lang\el
#   copying spacy\lang\el\tag_map_general.py -> build\lib.win-amd64-3.8\spacy\lang\el
#   copying spacy\lang\el\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\el
#   copying spacy\lang\el\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\el
#   creating build\lib.win-amd64-3.8\spacy\lang\en
#   copying spacy\lang\en\examples.py -> build\lib.win-amd64-3.8\spacy\lang\en
#   copying spacy\lang\en\lex_attrs.py -> build\lib.win-amd64-3.8\spacy\lang\en
#   copying spacy\lang\en\morph_rules.py -> build\lib.win-amd64-3.8\spacy\lang\en
#   copying spacy\lang\en\norm_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\en
#   copying spacy\lang\en\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\en
#   copying spacy\lang\en\syntax_iterators.py -> build\lib.win-amd64-3.8\spacy\lang\en
#   copying spacy\lang\en\tag_map.py -> build\lib.win-amd64-3.8\spacy\lang\en
#   copying spacy\lang\en\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\en
#   copying spacy\lang\en\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\en
#   creating build\lib.win-amd64-3.8\spacy\lang\es
#   copying spacy\lang\es\examples.py -> build\lib.win-amd64-3.8\spacy\lang\es
#   copying spacy\lang\es\lemmatizer.py -> build\lib.win-amd64-3.8\spacy\lang\es
#   copying spacy\lang\es\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\es
#   copying spacy\lang\es\syntax_iterators.py -> build\lib.win-amd64-3.8\spacy\lang\es
#   copying spacy\lang\es\tag_map.py -> build\lib.win-amd64-3.8\spacy\lang\es
#   copying spacy\lang\es\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\es
#   copying spacy\lang\es\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\es
#   creating build\lib.win-amd64-3.8\spacy\lang\fa
#   copying spacy\lang\fa\examples.py -> build\lib.win-amd64-3.8\spacy\lang\fa
#   copying spacy\lang\fa\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\fa
#   copying spacy\lang\fa\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\fa
#   creating build\lib.win-amd64-3.8\spacy\lang\fi
#   copying spacy\lang\fi\examples.py -> build\lib.win-amd64-3.8\spacy\lang\fi
#   copying spacy\lang\fi\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\fi
#   copying spacy\lang\fi\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\fi
#   copying spacy\lang\fi\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\fi
#   creating build\lib.win-amd64-3.8\spacy\lang\fr
#   copying spacy\lang\fr\examples.py -> build\lib.win-amd64-3.8\spacy\lang\fr
#   copying spacy\lang\fr\lemmatizer.py -> build\lib.win-amd64-3.8\spacy\lang\fr
#   copying spacy\lang\fr\lex_attrs.py -> build\lib.win-amd64-3.8\spacy\lang\fr
#   copying spacy\lang\fr\punctuation.py -> build\lib.win-amd64-3.8\spacy\lang\fr
#   copying spacy\lang\fr\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\fr
#   copying spacy\lang\fr\syntax_iterators.py -> build\lib.win-amd64-3.8\spacy\lang\fr
#   copying spacy\lang\fr\tag_map.py -> build\lib.win-amd64-3.8\spacy\lang\fr
#   copying spacy\lang\fr\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\fr
#   copying spacy\lang\fr\_tokenizer_exceptions_list.py -> build\lib.win-amd64-3.8\spacy\lang\fr
#   copying spacy\lang\fr\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\fr
#   creating build\lib.win-amd64-3.8\spacy\lang\ga
#   copying spacy\lang\ga\irish_morphology_helpers.py -> build\lib.win-amd64-3.8\spacy\lang\ga
#   copying spacy\lang\ga\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\ga
#   copying spacy\lang\ga\tag_map.py -> build\lib.win-amd64-3.8\spacy\lang\ga
#   copying spacy\lang\ga\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\ga
#   copying spacy\lang\ga\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\ga
#   creating build\lib.win-amd64-3.8\spacy\lang\he
#   copying spacy\lang\he\examples.py -> build\lib.win-amd64-3.8\spacy\lang\he
#   copying spacy\lang\he\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\he
#   copying spacy\lang\he\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\he
#   creating build\lib.win-amd64-3.8\spacy\lang\hi
#   copying spacy\lang\hi\examples.py -> build\lib.win-amd64-3.8\spacy\lang\hi
#   copying spacy\lang\hi\lex_attrs.py -> build\lib.win-amd64-3.8\spacy\lang\hi
#   copying spacy\lang\hi\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\hi
#   copying spacy\lang\hi\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\hi
#   creating build\lib.win-amd64-3.8\spacy\lang\hr
#   copying spacy\lang\hr\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\hr
#   copying spacy\lang\hr\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\hr
#   creating build\lib.win-amd64-3.8\spacy\lang\hu
#   copying spacy\lang\hu\examples.py -> build\lib.win-amd64-3.8\spacy\lang\hu
#   copying spacy\lang\hu\lemmatizer.py -> build\lib.win-amd64-3.8\spacy\lang\hu
#   copying spacy\lang\hu\punctuation.py -> build\lib.win-amd64-3.8\spacy\lang\hu
#   copying spacy\lang\hu\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\hu
#   copying spacy\lang\hu\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\hu
#   copying spacy\lang\hu\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\hu
#   creating build\lib.win-amd64-3.8\spacy\lang\id
#   copying spacy\lang\id\examples.py -> build\lib.win-amd64-3.8\spacy\lang\id
#   copying spacy\lang\id\lemmatizer.py -> build\lib.win-amd64-3.8\spacy\lang\id
#   copying spacy\lang\id\lex_attrs.py -> build\lib.win-amd64-3.8\spacy\lang\id
#   copying spacy\lang\id\norm_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\id
#   copying spacy\lang\id\punctuation.py -> build\lib.win-amd64-3.8\spacy\lang\id
#   copying spacy\lang\id\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\id
#   copying spacy\lang\id\syntax_iterators.py -> build\lib.win-amd64-3.8\spacy\lang\id
#   copying spacy\lang\id\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\id
#   copying spacy\lang\id\_tokenizer_exceptions_list.py -> build\lib.win-amd64-3.8\spacy\lang\id
#   copying spacy\lang\id\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\id
#   creating build\lib.win-amd64-3.8\spacy\lang\it
#   copying spacy\lang\it\examples.py -> build\lib.win-amd64-3.8\spacy\lang\it
#   copying spacy\lang\it\lemmatizer.py -> build\lib.win-amd64-3.8\spacy\lang\it
#   copying spacy\lang\it\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\it
#   copying spacy\lang\it\tag_map.py -> build\lib.win-amd64-3.8\spacy\lang\it
#   copying spacy\lang\it\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\it
#   creating build\lib.win-amd64-3.8\spacy\lang\ja
#   copying spacy\lang\ja\examples.py -> build\lib.win-amd64-3.8\spacy\lang\ja
#   copying spacy\lang\ja\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\ja
#   copying spacy\lang\ja\tag_map.py -> build\lib.win-amd64-3.8\spacy\lang\ja
#   copying spacy\lang\ja\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\ja
#   creating build\lib.win-amd64-3.8\spacy\lang\nb
#   copying spacy\lang\nb\examples.py -> build\lib.win-amd64-3.8\spacy\lang\nb
#   copying spacy\lang\nb\morph_rules.py -> build\lib.win-amd64-3.8\spacy\lang\nb
#   copying spacy\lang\nb\punctuation.py -> build\lib.win-amd64-3.8\spacy\lang\nb
#   copying spacy\lang\nb\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\nb
#   copying spacy\lang\nb\syntax_iterators.py -> build\lib.win-amd64-3.8\spacy\lang\nb
#   copying spacy\lang\nb\tag_map.py -> build\lib.win-amd64-3.8\spacy\lang\nb
#   copying spacy\lang\nb\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\nb
#   copying spacy\lang\nb\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\nb
#   creating build\lib.win-amd64-3.8\spacy\lang\nl
#   copying spacy\lang\nl\examples.py -> build\lib.win-amd64-3.8\spacy\lang\nl
#   copying spacy\lang\nl\lex_attrs.py -> build\lib.win-amd64-3.8\spacy\lang\nl
#   copying spacy\lang\nl\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\nl
#   copying spacy\lang\nl\tag_map.py -> build\lib.win-amd64-3.8\spacy\lang\nl
#   copying spacy\lang\nl\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\nl
#   creating build\lib.win-amd64-3.8\spacy\lang\pl
#   copying spacy\lang\pl\examples.py -> build\lib.win-amd64-3.8\spacy\lang\pl
#   copying spacy\lang\pl\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\pl
#   copying spacy\lang\pl\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\pl
#   copying spacy\lang\pl\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\pl
#   creating build\lib.win-amd64-3.8\spacy\lang\pt
#   copying spacy\lang\pt\examples.py -> build\lib.win-amd64-3.8\spacy\lang\pt
#   copying spacy\lang\pt\lemmatizer.py -> build\lib.win-amd64-3.8\spacy\lang\pt
#   copying spacy\lang\pt\lex_attrs.py -> build\lib.win-amd64-3.8\spacy\lang\pt
#   copying spacy\lang\pt\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\pt
#   copying spacy\lang\pt\tag_map.py -> build\lib.win-amd64-3.8\spacy\lang\pt
#   copying spacy\lang\pt\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\pt
#   copying spacy\lang\pt\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\pt
#   creating build\lib.win-amd64-3.8\spacy\lang\ro
#   copying spacy\lang\ro\examples.py -> build\lib.win-amd64-3.8\spacy\lang\ro
#   copying spacy\lang\ro\lemmatizer.py -> build\lib.win-amd64-3.8\spacy\lang\ro
#   copying spacy\lang\ro\lex_attrs.py -> build\lib.win-amd64-3.8\spacy\lang\ro
#   copying spacy\lang\ro\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\ro
#   copying spacy\lang\ro\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\ro
#   copying spacy\lang\ro\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\ro
#   creating build\lib.win-amd64-3.8\spacy\lang\ru
#   copying spacy\lang\ru\examples.py -> build\lib.win-amd64-3.8\spacy\lang\ru
#   copying spacy\lang\ru\lemmatizer.py -> build\lib.win-amd64-3.8\spacy\lang\ru
#   copying spacy\lang\ru\lex_attrs.py -> build\lib.win-amd64-3.8\spacy\lang\ru
#   copying spacy\lang\ru\norm_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\ru
#   copying spacy\lang\ru\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\ru
#   copying spacy\lang\ru\tag_map.py -> build\lib.win-amd64-3.8\spacy\lang\ru
#   copying spacy\lang\ru\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\ru
#   copying spacy\lang\ru\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\ru
#   creating build\lib.win-amd64-3.8\spacy\lang\sv
#   copying spacy\lang\sv\examples.py -> build\lib.win-amd64-3.8\spacy\lang\sv
#   copying spacy\lang\sv\morph_rules.py -> build\lib.win-amd64-3.8\spacy\lang\sv
#   copying spacy\lang\sv\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\sv
#   copying spacy\lang\sv\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\sv
#   copying spacy\lang\sv\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\sv
#   creating build\lib.win-amd64-3.8\spacy\lang\th
#   copying spacy\lang\th\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\th
#   copying spacy\lang\th\tag_map.py -> build\lib.win-amd64-3.8\spacy\lang\th
#   copying spacy\lang\th\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\th
#   copying spacy\lang\th\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\th
#   creating build\lib.win-amd64-3.8\spacy\lang\tr
#   copying spacy\lang\tr\examples.py -> build\lib.win-amd64-3.8\spacy\lang\tr
#   copying spacy\lang\tr\lemmatizer.py -> build\lib.win-amd64-3.8\spacy\lang\tr
#   copying spacy\lang\tr\lex_attrs.py -> build\lib.win-amd64-3.8\spacy\lang\tr
#   copying spacy\lang\tr\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\tr
#   copying spacy\lang\tr\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\tr
#   copying spacy\lang\tr\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\tr
#   creating build\lib.win-amd64-3.8\spacy\lang\tt
#   copying spacy\lang\tt\examples.py -> build\lib.win-amd64-3.8\spacy\lang\tt
#   copying spacy\lang\tt\lex_attrs.py -> build\lib.win-amd64-3.8\spacy\lang\tt
#   copying spacy\lang\tt\punctuation.py -> build\lib.win-amd64-3.8\spacy\lang\tt
#   copying spacy\lang\tt\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\tt
#   copying spacy\lang\tt\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\tt
#   copying spacy\lang\tt\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\tt
#   creating build\lib.win-amd64-3.8\spacy\lang\ur
#   copying spacy\lang\ur\examples.py -> build\lib.win-amd64-3.8\spacy\lang\ur
#   copying spacy\lang\ur\lemmatizer.py -> build\lib.win-amd64-3.8\spacy\lang\ur
#   copying spacy\lang\ur\lex_attrs.py -> build\lib.win-amd64-3.8\spacy\lang\ur
#   copying spacy\lang\ur\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\ur
#   copying spacy\lang\ur\tag_map.py -> build\lib.win-amd64-3.8\spacy\lang\ur
#   copying spacy\lang\ur\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\ur
#   copying spacy\lang\ur\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\ur
#   creating build\lib.win-amd64-3.8\spacy\lang\vi
#   copying spacy\lang\vi\lex_attrs.py -> build\lib.win-amd64-3.8\spacy\lang\vi
#   copying spacy\lang\vi\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\vi
#   copying spacy\lang\vi\tag_map.py -> build\lib.win-amd64-3.8\spacy\lang\vi
#   copying spacy\lang\vi\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\vi
#   creating build\lib.win-amd64-3.8\spacy\lang\xx
#   copying spacy\lang\xx\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\xx
#   creating build\lib.win-amd64-3.8\spacy\lang\zh
#   copying spacy\lang\zh\examples.py -> build\lib.win-amd64-3.8\spacy\lang\zh
#   copying spacy\lang\zh\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\zh
#   creating build\lib.win-amd64-3.8\spacy\lang\el\lemmatizer
#   copying spacy\lang\el\lemmatizer\get_pos_from_wiktionary.py -> build\lib.win-amd64-3.8\spacy\lang\el\lemmatizer
#   copying spacy\lang\el\lemmatizer\_adjectives.py -> build\lib.win-amd64-3.8\spacy\lang\el\lemmatizer
#   copying spacy\lang\el\lemmatizer\_adjectives_irreg.py -> build\lib.win-amd64-3.8\spacy\lang\el\lemmatizer
#   copying spacy\lang\el\lemmatizer\_adverbs.py -> build\lib.win-amd64-3.8\spacy\lang\el\lemmatizer
#   copying spacy\lang\el\lemmatizer\_dets.py -> build\lib.win-amd64-3.8\spacy\lang\el\lemmatizer
#   copying spacy\lang\el\lemmatizer\_dets_irreg.py -> build\lib.win-amd64-3.8\spacy\lang\el\lemmatizer
#   copying spacy\lang\el\lemmatizer\_lemma_rules.py -> build\lib.win-amd64-3.8\spacy\lang\el\lemmatizer
#   copying spacy\lang\el\lemmatizer\_nouns.py -> build\lib.win-amd64-3.8\spacy\lang\el\lemmatizer
#   copying spacy\lang\el\lemmatizer\_nouns_irreg.py -> build\lib.win-amd64-3.8\spacy\lang\el\lemmatizer
#   copying spacy\lang\el\lemmatizer\_participles.py -> build\lib.win-amd64-3.8\spacy\lang\el\lemmatizer
#   copying spacy\lang\el\lemmatizer\_proper_names.py -> build\lib.win-amd64-3.8\spacy\lang\el\lemmatizer
#   copying spacy\lang\el\lemmatizer\_verbs.py -> build\lib.win-amd64-3.8\spacy\lang\el\lemmatizer
#   copying spacy\lang\el\lemmatizer\_verbs_irreg.py -> build\lib.win-amd64-3.8\spacy\lang\el\lemmatizer
#   copying spacy\lang\el\lemmatizer\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\el\lemmatizer
#   creating build\lib.win-amd64-3.8\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\lookup.py -> build\lib.win-amd64-3.8\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\_adjectives.py -> build\lib.win-amd64-3.8\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\_adjectives_irreg.py -> build\lib.win-amd64-3.8\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\_adverbs.py -> build\lib.win-amd64-3.8\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\_adverbs_irreg.py -> build\lib.win-amd64-3.8\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\_lemma_rules.py -> build\lib.win-amd64-3.8\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\_nouns.py -> build\lib.win-amd64-3.8\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\_nouns_irreg.py -> build\lib.win-amd64-3.8\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\_verbs.py -> build\lib.win-amd64-3.8\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\_verbs_irreg.py -> build\lib.win-amd64-3.8\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\en\lemmatizer
#   creating build\lib.win-amd64-3.8\spacy\lang\nb\lemmatizer
#   copying spacy\lang\nb\lemmatizer\lookup.py -> build\lib.win-amd64-3.8\spacy\lang\nb\lemmatizer
#   copying spacy\lang\nb\lemmatizer\_adjectives.py -> build\lib.win-amd64-3.8\spacy\lang\nb\lemmatizer
#   copying spacy\lang\nb\lemmatizer\_adjectives_wordforms.py -> build\lib.win-amd64-3.8\spacy\lang\nb\lemmatizer
#   copying spacy\lang\nb\lemmatizer\_adverbs.py -> build\lib.win-amd64-3.8\spacy\lang\nb\lemmatizer
#   copying spacy\lang\nb\lemmatizer\_adverbs_wordforms.py -> build\lib.win-amd64-3.8\spacy\lang\nb\lemmatizer
#   copying spacy\lang\nb\lemmatizer\_lemma_rules.py -> build\lib.win-amd64-3.8\spacy\lang\nb\lemmatizer
#   copying spacy\lang\nb\lemmatizer\_nouns.py -> build\lib.win-amd64-3.8\spacy\lang\nb\lemmatizer
#   copying spacy\lang\nb\lemmatizer\_nouns_wordforms.py -> build\lib.win-amd64-3.8\spacy\lang\nb\lemmatizer
#   copying spacy\lang\nb\lemmatizer\_verbs.py -> build\lib.win-amd64-3.8\spacy\lang\nb\lemmatizer
#   copying spacy\lang\nb\lemmatizer\_verbs_wordforms.py -> build\lib.win-amd64-3.8\spacy\lang\nb\lemmatizer
#   copying spacy\lang\nb\lemmatizer\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\nb\lemmatizer
#   creating build\lib.win-amd64-3.8\spacy\lang\sv\lemmatizer
#   copying spacy\lang\sv\lemmatizer\lookup.py -> build\lib.win-amd64-3.8\spacy\lang\sv\lemmatizer
#   copying spacy\lang\sv\lemmatizer\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\sv\lemmatizer
#   creating build\lib.win-amd64-3.8\spacy\tests\doc
#   copying spacy\tests\doc\test_add_entities.py -> build\lib.win-amd64-3.8\spacy\tests\doc
#   copying spacy\tests\doc\test_array.py -> build\lib.win-amd64-3.8\spacy\tests\doc
#   copying spacy\tests\doc\test_creation.py -> build\lib.win-amd64-3.8\spacy\tests\doc
#   copying spacy\tests\doc\test_doc_api.py -> build\lib.win-amd64-3.8\spacy\tests\doc
#   copying spacy\tests\doc\test_pickle_doc.py -> build\lib.win-amd64-3.8\spacy\tests\doc
#   copying spacy\tests\doc\test_span.py -> build\lib.win-amd64-3.8\spacy\tests\doc
#   copying spacy\tests\doc\test_span_merge.py -> build\lib.win-amd64-3.8\spacy\tests\doc
#   copying spacy\tests\doc\test_token_api.py -> build\lib.win-amd64-3.8\spacy\tests\doc
#   copying spacy\tests\doc\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\doc
#   creating build\lib.win-amd64-3.8\spacy\tests\gold
#   copying spacy\tests\gold\test_biluo.py -> build\lib.win-amd64-3.8\spacy\tests\gold
#   copying spacy\tests\gold\test_lev_align.py -> build\lib.win-amd64-3.8\spacy\tests\gold
#   copying spacy\tests\gold\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\gold
#   creating build\lib.win-amd64-3.8\spacy\tests\lang
#   copying spacy\tests\lang\test_attrs.py -> build\lib.win-amd64-3.8\spacy\tests\lang
#   copying spacy\tests\lang\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\lang
#   creating build\lib.win-amd64-3.8\spacy\tests\parser
#   copying spacy\tests\parser\test_add_label.py -> build\lib.win-amd64-3.8\spacy\tests\parser
#   copying spacy\tests\parser\test_beam_parse.py -> build\lib.win-amd64-3.8\spacy\tests\parser
#   copying spacy\tests\parser\test_ner.py -> build\lib.win-amd64-3.8\spacy\tests\parser
#   copying spacy\tests\parser\test_neural_parser.py -> build\lib.win-amd64-3.8\spacy\tests\parser
#   copying spacy\tests\parser\test_nn_beam.py -> build\lib.win-amd64-3.8\spacy\tests\parser
#   copying spacy\tests\parser\test_nonproj.py -> build\lib.win-amd64-3.8\spacy\tests\parser
#   copying spacy\tests\parser\test_parse.py -> build\lib.win-amd64-3.8\spacy\tests\parser
#   copying spacy\tests\parser\test_parse_navigate.py -> build\lib.win-amd64-3.8\spacy\tests\parser
#   copying spacy\tests\parser\test_preset_sbd.py -> build\lib.win-amd64-3.8\spacy\tests\parser
#   copying spacy\tests\parser\test_space_attachment.py -> build\lib.win-amd64-3.8\spacy\tests\parser
#   copying spacy\tests\parser\test_to_from_bytes_disk.py -> build\lib.win-amd64-3.8\spacy\tests\parser
#   copying spacy\tests\parser\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\parser
#   creating build\lib.win-amd64-3.8\spacy\tests\pipeline
#   copying spacy\tests\pipeline\test_factories.py -> build\lib.win-amd64-3.8\spacy\tests\pipeline
#   copying spacy\tests\pipeline\test_pipe_methods.py -> build\lib.win-amd64-3.8\spacy\tests\pipeline
#   copying spacy\tests\pipeline\test_textcat.py -> build\lib.win-amd64-3.8\spacy\tests\pipeline
#   copying spacy\tests\pipeline\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\pipeline
#   creating build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue118.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1207.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1242.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1250.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1253.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1257.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1305.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1375.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1380.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1387.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1434.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1450.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1488.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1494.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1506.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1518.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1537.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1539.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1547.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1612.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1622.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1654.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1660.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1698.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1727.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1757.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1758.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1769.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1799.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1807.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1834.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1868.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1883.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1915.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1919.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1945.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1959.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1967.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue2179.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue2219.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue2361.py -> build\lib.win-amd64-3.8\spacy\tests\regression
# ...
#   copying thinc\neural\vec2vec.py -> build\lib.win-amd64-3.8\thinc\neural
#   copying thinc\neural\vecs2vec.py -> build\lib.win-amd64-3.8\thinc\neural
#   copying thinc\neural\vecs2vecs.py -> build\lib.win-amd64-3.8\thinc\neural
#   copying thinc\neural\_lsuv.py -> build\lib.win-amd64-3.8\thinc\neural
#   copying thinc\neural\__init__.py -> build\lib.win-amd64-3.8\thinc\neural
#   creating build\lib.win-amd64-3.8\thinc\extra
#   copying thinc\extra\datasets.py -> build\lib.win-amd64-3.8\thinc\extra
#   copying thinc\extra\hpbff.py -> build\lib.win-amd64-3.8\thinc\extra
#   copying thinc\extra\load_nlp.py -> build\lib.win-amd64-3.8\thinc\extra
#   copying thinc\extra\wrappers.py -> build\lib.win-amd64-3.8\thinc\extra
#   copying thinc\extra\__init__.py -> build\lib.win-amd64-3.8\thinc\extra
#   creating build\lib.win-amd64-3.8\thinc\neural\_classes
#   copying thinc\neural\_classes\affine.py -> build\lib.win-amd64-3.8\thinc\neural\_classes
#   copying thinc\neural\_classes\attention.py -> build\lib.win-amd64-3.8\thinc\neural\_classes
#   copying thinc\neural\_classes\batchnorm.py -> build\lib.win-amd64-3.8\thinc\neural\_classes
#   copying thinc\neural\_classes\convolution.py -> build\lib.win-amd64-3.8\thinc\neural\_classes
#   copying thinc\neural\_classes\difference.py -> build\lib.win-amd64-3.8\thinc\neural\_classes
#   copying thinc\neural\_classes\elu.py -> build\lib.win-amd64-3.8\thinc\neural\_classes
#   copying thinc\neural\_classes\embed.py -> build\lib.win-amd64-3.8\thinc\neural\_classes
#   copying thinc\neural\_classes\feed_forward.py -> build\lib.win-amd64-3.8\thinc\neural\_classes
#   copying thinc\neural\_classes\hash_embed.py -> build\lib.win-amd64-3.8\thinc\neural\_classes
#   copying thinc\neural\_classes\layernorm.py -> build\lib.win-amd64-3.8\thinc\neural\_classes
#   copying thinc\neural\_classes\lstm.py -> build\lib.win-amd64-3.8\thinc\neural\_classes
#   copying thinc\neural\_classes\maxout.py -> build\lib.win-amd64-3.8\thinc\neural\_classes
#   copying thinc\neural\_classes\model.py -> build\lib.win-amd64-3.8\thinc\neural\_classes
#   copying thinc\neural\_classes\relu.py -> build\lib.win-amd64-3.8\thinc\neural\_classes
#   copying thinc\neural\_classes\resnet.py -> build\lib.win-amd64-3.8\thinc\neural\_classes
#   copying thinc\neural\_classes\rnn.py -> build\lib.win-amd64-3.8\thinc\neural\_classes
#   copying thinc\neural\_classes\selu.py -> build\lib.win-amd64-3.8\thinc\neural\_classes
#   copying thinc\neural\_classes\softmax.py -> build\lib.win-amd64-3.8\thinc\neural\_classes
#   copying thinc\neural\_classes\static_vectors.py -> build\lib.win-amd64-3.8\thinc\neural\_classes
#   copying thinc\neural\_classes\__init__.py -> build\lib.win-amd64-3.8\thinc\neural\_classes
#   creating build\lib.win-amd64-3.8\thinc\extra\_vendorized
#   copying thinc\extra\_vendorized\keras_datasets.py -> build\lib.win-amd64-3.8\thinc\extra\_vendorized
#   copying thinc\extra\_vendorized\keras_data_utils.py -> build\lib.win-amd64-3.8\thinc\extra\_vendorized
#   copying thinc\extra\_vendorized\keras_generic_utils.py -> build\lib.win-amd64-3.8\thinc\extra\_vendorized
#   copying thinc\extra\_vendorized\__init__.py -> build\lib.win-amd64-3.8\thinc\extra\_vendorized
#   copying thinc\linalg.pyx -> build\lib.win-amd64-3.8\thinc
#   copying thinc\structs.pyx -> build\lib.win-amd64-3.8\thinc
#   copying thinc\typedefs.pyx -> build\lib.win-amd64-3.8\thinc
#   copying thinc\linalg.pxd -> build\lib.win-amd64-3.8\thinc
#   copying thinc\structs.pxd -> build\lib.win-amd64-3.8\thinc
#   copying thinc\typedefs.pxd -> build\lib.win-amd64-3.8\thinc
#   copying thinc\__init__.pxd -> build\lib.win-amd64-3.8\thinc
#   copying thinc\compile_time_constants.pxi -> build\lib.win-amd64-3.8\thinc
#   copying thinc\linalg.cpp -> build\lib.win-amd64-3.8\thinc
#   copying thinc\structs.cpp -> build\lib.win-amd64-3.8\thinc
#   copying thinc\typedefs.cpp -> build\lib.win-amd64-3.8\thinc
#   copying thinc\linear\avgtron.pyx -> build\lib.win-amd64-3.8\thinc\linear
#   copying thinc\linear\features.pyx -> build\lib.win-amd64-3.8\thinc\linear
#   copying thinc\linear\linear.pyx -> build\lib.win-amd64-3.8\thinc\linear
#   copying thinc\linear\serialize.pyx -> build\lib.win-amd64-3.8\thinc\linear
#   copying thinc\linear\sparse.pyx -> build\lib.win-amd64-3.8\thinc\linear
#   copying thinc\linear\avgtron.pxd -> build\lib.win-amd64-3.8\thinc\linear
#   copying thinc\linear\features.pxd -> build\lib.win-amd64-3.8\thinc\linear
#   copying thinc\linear\serialize.pxd -> build\lib.win-amd64-3.8\thinc\linear
#   copying thinc\linear\sparse.pxd -> build\lib.win-amd64-3.8\thinc\linear
#   copying thinc\linear\__init__.pxd -> build\lib.win-amd64-3.8\thinc\linear
#   copying thinc\linear\avgtron.cpp -> build\lib.win-amd64-3.8\thinc\linear
#   copying thinc\linear\features.cpp -> build\lib.win-amd64-3.8\thinc\linear
#   copying thinc\linear\linear.cpp -> build\lib.win-amd64-3.8\thinc\linear
#   copying thinc\linear\serialize.cpp -> build\lib.win-amd64-3.8\thinc\linear
#   copying thinc\linear\sparse.cpp -> build\lib.win-amd64-3.8\thinc\linear
#   copying thinc\neural\gpu_ops.pyx -> build\lib.win-amd64-3.8\thinc\neural
#   copying thinc\neural\ops.pyx -> build\lib.win-amd64-3.8\thinc\neural
#   copying thinc\neural\optimizers.pyx -> build\lib.win-amd64-3.8\thinc\neural
#   copying thinc\neural\_funcs.pyx -> build\lib.win-amd64-3.8\thinc\neural
#   copying thinc\neural\ops.pxd -> build\lib.win-amd64-3.8\thinc\neural
#   copying thinc\neural\_funcs.pxd -> build\lib.win-amd64-3.8\thinc\neural
#   copying thinc\neural\__init__.pxd -> build\lib.win-amd64-3.8\thinc\neural
#   copying thinc\neural\gpu_ops.cpp -> build\lib.win-amd64-3.8\thinc\neural
#   copying thinc\neural\ops.cpp -> build\lib.win-amd64-3.8\thinc\neural
#   copying thinc\neural\optimizers.cpp -> build\lib.win-amd64-3.8\thinc\neural
#   copying thinc\neural\_funcs.cpp -> build\lib.win-amd64-3.8\thinc\neural
#   copying thinc\extra\cache.pyx -> build\lib.win-amd64-3.8\thinc\extra
#   copying thinc\extra\eg.pyx -> build\lib.win-amd64-3.8\thinc\extra
#   copying thinc\extra\mb.pyx -> build\lib.win-amd64-3.8\thinc\extra
#   copying thinc\extra\search.pyx -> build\lib.win-amd64-3.8\thinc\extra
#   copying thinc\extra\cache.pxd -> build\lib.win-amd64-3.8\thinc\extra
#   copying thinc\extra\eg.pxd -> build\lib.win-amd64-3.8\thinc\extra
#   copying thinc\extra\mb.pxd -> build\lib.win-amd64-3.8\thinc\extra
#   copying thinc\extra\search.pxd -> build\lib.win-amd64-3.8\thinc\extra
#   copying thinc\extra\__init__.pxd -> build\lib.win-amd64-3.8\thinc\extra
#   copying thinc\extra\cache.cpp -> build\lib.win-amd64-3.8\thinc\extra
#   copying thinc\extra\eg.cpp -> build\lib.win-amd64-3.8\thinc\extra
#   copying thinc\extra\mb.cpp -> build\lib.win-amd64-3.8\thinc\extra
#   copying thinc\extra\search.cpp -> build\lib.win-amd64-3.8\thinc\extra
#   running build_ext
#   building 'thinc.linalg' extension
#   creating build\temp.win-amd64-3.8
#   creating build\temp.win-amd64-3.8\Release
#   creating build\temp.win-amd64-3.8\Release\thinc
#   C:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.28.29910\bin\HostX86\x64\cl.exe /c /nologo /Ox /W3 /GL /DNDEBUG /MD -Ic:\users\erdin\anaconda3\include -IC:\Users\erdin\AppData\Local\Temp\pip-install-5_87qyxw\thinc_1564079a649a422f9595038fe473fd70\include -Ic:\users\erdin\anaconda3\include -Ic:\users\erdin\anaconda3\include "-IC:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.28.29910\include" "-IC:\Program Files (x86)\Windows Kits\NETFXSDK\4.8\include\um" /EHsc /Tpthinc/linalg.cpp /Fobuild\temp.win-amd64-3.8\Release\thinc/linalg.obj /Ox /EHsc
#   linalg.cpp
#   c:\users\erdin\anaconda3\include\pyconfig.h(59): fatal error C1083: i‡erme dosyas\x8d a‡\x8dlam\x8dyor: 'io.h': No such file or directory
#   error: command 'C:\\Program Files (x86)\\Microsoft Visual Studio\\2019\\Community\\VC\\Tools\\MSVC\\14.28.29910\\bin\\HostX86\\x64\\cl.exe' failed with exit status 2
#   ----------------------------------------
#   ERROR: Failed building wheel for thinc
#   ERROR: Command errored out with exit status 1:
#    command: 'c:\users\erdin\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\erdin\\AppData\\Local\\Temp\\pip-install-5_87qyxw\\cytoolz_42a0f63799ef45ff82fad70fa7e1547f\\setup.py'"'"'; __file__='"'"'C:\\Users\\erdin\\AppData\\Local\\Temp\\pip-install-5_87qyxw\\cytoolz_42a0f63799ef45ff82fad70fa7e1547f\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\erdin\AppData\Local\Temp\pip-wheel-znr2mcl2'
#        cwd: C:\Users\erdin\AppData\Local\Temp\pip-install-5_87qyxw\cytoolz_42a0f63799ef45ff82fad70fa7e1547f\
#   Complete output (55 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.8
#   creating build\lib.win-amd64-3.8\cytoolz
#   copying cytoolz\compatibility.py -> build\lib.win-amd64-3.8\cytoolz
#   copying cytoolz\utils_test.py -> build\lib.win-amd64-3.8\cytoolz
#   copying cytoolz\_signatures.py -> build\lib.win-amd64-3.8\cytoolz
#   copying cytoolz\_version.py -> build\lib.win-amd64-3.8\cytoolz
#   copying cytoolz\__init__.py -> build\lib.win-amd64-3.8\cytoolz
#   creating build\lib.win-amd64-3.8\cytoolz\curried
#   copying cytoolz\curried\exceptions.py -> build\lib.win-amd64-3.8\cytoolz\curried
#   copying cytoolz\curried\operator.py -> build\lib.win-amd64-3.8\cytoolz\curried
#   copying cytoolz\curried\__init__.py -> build\lib.win-amd64-3.8\cytoolz\curried
#   copying cytoolz\dicttoolz.pyx -> build\lib.win-amd64-3.8\cytoolz
#   copying cytoolz\functoolz.pyx -> build\lib.win-amd64-3.8\cytoolz
#   copying cytoolz\itertoolz.pyx -> build\lib.win-amd64-3.8\cytoolz
#   copying cytoolz\recipes.pyx -> build\lib.win-amd64-3.8\cytoolz
#   copying cytoolz\utils.pyx -> build\lib.win-amd64-3.8\cytoolz
#   copying cytoolz\cpython.pxd -> build\lib.win-amd64-3.8\cytoolz
#   copying cytoolz\dicttoolz.pxd -> build\lib.win-amd64-3.8\cytoolz
#   copying cytoolz\functoolz.pxd -> build\lib.win-amd64-3.8\cytoolz
#   copying cytoolz\itertoolz.pxd -> build\lib.win-amd64-3.8\cytoolz
#   copying cytoolz\recipes.pxd -> build\lib.win-amd64-3.8\cytoolz
#   copying cytoolz\utils.pxd -> build\lib.win-amd64-3.8\cytoolz
#   copying cytoolz\__init__.pxd -> build\lib.win-amd64-3.8\cytoolz
#   creating build\lib.win-amd64-3.8\cytoolz\tests
#   copying cytoolz\tests\dev_skip_test.py -> build\lib.win-amd64-3.8\cytoolz\tests
#   copying cytoolz\tests\test_compatibility.py -> build\lib.win-amd64-3.8\cytoolz\tests
#   copying cytoolz\tests\test_curried.py -> build\lib.win-amd64-3.8\cytoolz\tests
#   copying cytoolz\tests\test_curried_toolzlike.py -> build\lib.win-amd64-3.8\cytoolz\tests
#   copying cytoolz\tests\test_dev_skip_test.py -> build\lib.win-amd64-3.8\cytoolz\tests
#   copying cytoolz\tests\test_dicttoolz.py -> build\lib.win-amd64-3.8\cytoolz\tests
#   copying cytoolz\tests\test_docstrings.py -> build\lib.win-amd64-3.8\cytoolz\tests
#   copying cytoolz\tests\test_doctests.py -> build\lib.win-amd64-3.8\cytoolz\tests
#   copying cytoolz\tests\test_embedded_sigs.py -> build\lib.win-amd64-3.8\cytoolz\tests
#   copying cytoolz\tests\test_functoolz.py -> build\lib.win-amd64-3.8\cytoolz\tests
#   copying cytoolz\tests\test_inspect_args.py -> build\lib.win-amd64-3.8\cytoolz\tests
#   copying cytoolz\tests\test_itertoolz.py -> build\lib.win-amd64-3.8\cytoolz\tests
#   copying cytoolz\tests\test_none_safe.py -> build\lib.win-amd64-3.8\cytoolz\tests
#   copying cytoolz\tests\test_recipes.py -> build\lib.win-amd64-3.8\cytoolz\tests
#   copying cytoolz\tests\test_serialization.py -> build\lib.win-amd64-3.8\cytoolz\tests
#   copying cytoolz\tests\test_signatures.py -> build\lib.win-amd64-3.8\cytoolz\tests
#   copying cytoolz\tests\test_tlz.py -> build\lib.win-amd64-3.8\cytoolz\tests
#   copying cytoolz\tests\test_utils.py -> build\lib.win-amd64-3.8\cytoolz\tests
#   running build_ext
#   building 'cytoolz.dicttoolz' extension
#   creating build\temp.win-amd64-3.8
#   creating build\temp.win-amd64-3.8\Release
#   creating build\temp.win-amd64-3.8\Release\cytoolz
#   C:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.28.29910\bin\HostX86\x64\cl.exe /c /nologo /Ox /W3 /GL /DNDEBUG /MD -Ic:\users\erdin\anaconda3\include -Ic:\users\erdin\anaconda3\include "-IC:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.28.29910\include" "-IC:\Program Files (x86)\Windows Kits\NETFXSDK\4.8\include\um" /Tccytoolz/dicttoolz.c /Fobuild\temp.win-amd64-3.8\Release\cytoolz/dicttoolz.obj
#   dicttoolz.c
#   c:\users\erdin\anaconda3\include\pyconfig.h(59): fatal error C1083: i‡erme dosyas\x8d a‡\x8dlam\x8dyor: 'io.h': No such file or directory
#   error: command 'C:\\Program Files (x86)\\Microsoft Visual Studio\\2019\\Community\\VC\\Tools\\MSVC\\14.28.29910\\bin\\HostX86\\x64\\cl.exe' failed with exit status 2
#   ----------------------------------------
#   ERROR: Failed building wheel for cytoolz
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\users\erdin\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\erdin\\AppData\\Local\\Temp\\pip-install-5_87qyxw\\cymem_4b089574c9e5434abeb54dc76e29f76e\\setup.py'"'"'; __file__='"'"'C:\\Users\\erdin\\AppData\\Local\\Temp\\pip-install-5_87qyxw\\cymem_4b089574c9e5434abeb54dc76e29f76e\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\erdin\AppData\Local\Temp\pip-record-t_rb_8_a\install-record.txt' --single-version-externally-managed --compile --install-headers 'c:\users\erdin\anaconda3\Include\cymem'
#          cwd: C:\Users\erdin\AppData\Local\Temp\pip-install-5_87qyxw\cymem_4b089574c9e5434abeb54dc76e29f76e\
#     Complete output (10 lines):
#     running install
#     running build
#     running build_py
#     package init file 'cymem\tests\__init__.py' not found (or not a regular file)
#     running build_ext
#     building 'cymem.cymem' extension
#     C:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.28.29910\bin\HostX86\x64\cl.exe /c /nologo /Ox /W3 /GL /DNDEBUG /MD -Ic:\users\erdin\anaconda3\include -Ic:\users\erdin\anaconda3\include -Ic:\users\erdin\anaconda3\include "-IC:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.28.29910\include" "-IC:\Program Files (x86)\Windows Kits\NETFXSDK\4.8\include\um" /EHsc /Tpcymem/cymem.cpp /Fobuild\temp.win-amd64-3.8\Release\cymem/cymem.obj /Ox /EHsc
#     cymem.cpp
#     c1xx: fatal error C1083: kaynak dosyas\x8d a‡\x8dlam\x8dyor: 'cymem/cymem.cpp': No such file or directory
#     error: command 'C:\\Program Files (x86)\\Microsoft Visual Studio\\2019\\Community\\VC\\Tools\\MSVC\\14.28.29910\\bin\\HostX86\\x64\\cl.exe' failed with exit status 2
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'c:\users\erdin\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\erdin\\AppData\\Local\\Temp\\pip-install-5_87qyxw\\cymem_4b089574c9e5434abeb54dc76e29f76e\\setup.py'"'"'; __file__='"'"'C:\\Users\\erdin\\AppData\\Local\\Temp\\pip-install-5_87qyxw\\cymem_4b089574c9e5434abeb54dc76e29f76e\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\erdin\AppData\Local\Temp\pip-record-t_rb_8_a\install-record.txt' --single-version-externally-managed --compile --install-headers 'c:\users\erdin\anaconda3\Include\cymem' Check the logs for full command output.

# %%
from summarizer import Summarizer,TransformerSummarizer

# %%
body = '''
       Scientists say they have discovered a new species of orangutans on Indonesia’s island of Sumatra.
The population differs in several ways from the two existing orangutan species found in Sumatra and the neighboring island of Borneo.
The orangutans were found inside North Sumatra’s Batang Toru forest, the science publication Current Biology reported.
Researchers named the new species the Tapanuli orangutan. They say the animals are considered a new species because of genetic, skeletal and tooth differences.
Michael Kruetzen is a geneticist with the University of Zurich who has studied the orangutans for several years. He said he was excited to be part of the unusual discovery of a new great ape in the present day. He noted that most great apes are currently considered endangered or severely endangered.
Gorillas, chimpanzees and bonobos also belong to the great ape species.
Orangutan – which means person of the forest in the Indonesian and Malay languages - is the world’s biggest tree-living mammal. The orange-haired animals can move easily among the trees because their arms are longer than their legs. They live more lonely lives than other great apes, spending a lot of time sleeping and eating fruit in the forest.
The new study said fewer than 800 of the newly-described orangutans exist. Their low numbers make the group the most endangered of all the great ape species.
They live within an area covering about 1,000 square kilometers. The population is considered highly vulnerable. That is because the environment which they depend on is greatly threatened by development.
Researchers say if steps are not taken quickly to reduce the current and future threats, the new species could become extinct “within our lifetime.”
Research into the new species began in 2013, when an orangutan protection group in Sumatra found an injured orangutan in an area far away from the other species. The adult male orangutan had been beaten by local villagers and died of his injuries. The complete skull was examined by researchers.
Among the physical differences of the new species are a notably smaller head and frizzier hair. The Tapanuli orangutans also have a different diet and are found only in higher forest areas.
There is no unified international system for recognizing new species. But to be considered, discovery claims at least require publication in a major scientific publication.
Russell Mittermeier is head of the primate specialist group at the International Union for the Conservation of Nature. He called the finding a “remarkable discovery.” He said it puts responsibility on the Indonesian government to help the species survive.
Matthew Nowak is one of the writers of the study. He told the Associated Press that there are three groups of the Tapanuli orangutans that are separated by non-protected land.He said forest land needs to connect the separated groups.
In addition, the writers of the study are recommending that plans for a hydropower center in the area be stopped by the government.
It also recommended that remaining forest in the Sumatran area where the orangutans live be protected.
I’m Bryan Lynn.

        '''

# %%
bert_model = Summarizer()
bert_summary = ''.join(bert_model(body, min_length=60))
print(bert_summary)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\transformers\modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#    1363                 try:
# -> 1364                     state_dict = torch.load(resolved_archive_file, map_location="cpu")
#    1365                 except Exception as e:
#
# ~\anaconda3\lib\site-packages\torch\serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     607                 return _load(opened_zipfile, map_location, pickle_module, **pickle_load_args)
# --> 608         return _legacy_load(opened_file, map_location, pickle_module, **pickle_load_args)
#     609
#
# ~\anaconda3\lib\site-packages\torch\serialization.py in _legacy_load(f, map_location, pickle_module, **pickle_load_args)
#     793         assert key in deserialized_objects
# --> 794         deserialized_objects[key]._set_from_file(f, offset, f_should_read_directly)
#     795         if offset is not None:
#
# RuntimeError: unexpected EOF, expected 120111654 more bytes. The file might be corrupted.
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\transformers\modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#    1367                         with open(resolved_archive_file) as f:
# -> 1368                             if f.read().startswith("version"):
#    1369                                 raise OSError(
#
# ~\anaconda3\lib\encodings\cp1254.py in decode(self, input, final)
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 2324: character maps to <undefined>
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-5-dfbf19de20fe> in <module>
# ----> 1 bert_model = Summarizer()
#       2 bert_summary = ''.join(bert_model(body, min_length=60))
#       3 print(bert_summary)
#
# ~\anaconda3\lib\site-packages\summarizer\bert.py in __init__(self, model, custom_model, custom_tokenizer, hidden, reduce_option, sentence_handler, random_state, hidden_concat, gpu_id)
#      79         """
#      80
# ---> 81         super(Summarizer, self).__init__(
#      82             model, custom_model, custom_tokenizer, hidden, reduce_option, sentence_handler, random_state, hidden_concat,
#      83             gpu_id
#
# ~\anaconda3\lib\site-packages\summarizer\bert.py in __init__(self, model, custom_model, custom_tokenizer, hidden, reduce_option, sentence_handler, random_state, hidden_concat, gpu_id)
#      47         :param gpu_id: GPU device index if CUDA is available.
#      48         """
# ---> 49         model = BertEmbedding(model, custom_model, custom_tokenizer, gpu_id)
#      50         model_func = partial(model, hidden=hidden, reduce_option=reduce_option, hidden_concat=hidden_concat)
#      51         super().__init__(model_func, sentence_handler, random_state)
#
# ~\anaconda3\lib\site-packages\summarizer\transformer_embeddings\bert_embedding.py in __init__(self, model, custom_model, custom_tokenizer, gpu_id)
#      50             self.model = custom_model.to(self.device)
#      51         else:
# ---> 52             self.model = base_model.from_pretrained(
#      53                 model, output_hidden_states=True).to(self.device)
#      54
#
# ~\anaconda3\lib\site-packages\transformers\modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#    1375                                 raise ValueError from e
#    1376                     except (UnicodeDecodeError, ValueError):
# -> 1377                         raise OSError(
#    1378                             f"Unable to load weights from pytorch checkpoint file for '{pretrained_model_name_or_path}' "
#    1379                             f"at '{resolved_archive_file}'. "
#
# OSError: Unable to load weights from pytorch checkpoint file for 'bert-large-uncased' at 'C:\Users\erdin/.cache\huggingface\transformers\1d959166dd7e047e57ea1b2d9b7b9669938a7e90c5e37a03961ad9f15eaea17f.fea64cd906e3766b04c92397f9ad3ff45271749cbe49829a079dd84e34c1697d'. If you tried to load a PyTorch model from a TF 2.0 checkpoint, please set from_tf=True.
